# %%
#AXIS
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[3,1,4,2,5]

plt.plot(x,y)
# plt.xticks(x,labels=["python","c","c++","java","R"])
# plt.yticks(x)

# plt.xlim(0,10)
# plt.ylim(0,10)

plt.axis([0,10,0,7])

plt.show()
