# %%
#BOX PLOT
# A Box Plot is also known as Whisker plot is created to display the summary of the set of data values having properties like minimum, first quartile, median, third quartile and maximum. 
# In the box plot, a box is created from the first quartile to the third quartile, a vertical line is also there which goes through the box at the median.

import matplotlib.pyplot as plt
x=[10,20,30,40,50,60,70,120]
plt.boxplot(x,widths=0.2,labels=["python"],showmeans=True,sym="g+",boxprops=dict(color="g"),capprops=dict(color="g"),whiskerprops=dict(color="g"))
            #notch=True,vert=False,patch_artist=True,his=3.5,flierprops=dict(markeredgecolor="b")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50,60,70]
x1=[20,30,40,50,60,80,90]
y=[x,x1]
plt.boxplot(y,labels=["python","c++"],showmeans=True,sym="g+",boxprops=dict(color="g"),capprops=dict(color="g"),whiskerprops=dict(color="g"))


plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
