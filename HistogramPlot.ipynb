# %%
#HISTOGRAM PLOT
# A histogram is a graph showing frequency distributions.
# It is a graph showing the number of observations within each given interval.

import matplotlib.pyplot as plt
import numpy as np
import random

x=np.random.randint(10,60,(50))
print(x)
# Out:
# [56 24 12 29 11 49 19 19 45 35 29 52 14 13 58 15 48 34 27 52 39 35 47 34
#  35 13 59 43 28 46 54 38 25 26 50 19 13 24 17 55 31 20 17 36 40 11 23 53
#  14 11]

# %%
n=[56, 24, 12, 29, 11, 49, 19, 19, 45, 35, 29, 52, 14, 13 ,58, 15, 48, 34, 27, 52, 39 ,35 ,47 ,34,35, 13, 59, 43, 28, 46, 54, 38, 25, 26, 50, 19 ,13 ,24 ,17 ,55, 31 ,20 ,17 ,36 ,40 ,11 ,23 ,53
   ,14 ,11]
l=[10,20,30,40,50,60]

# plt.hist(n,"auto",(0,200),edgecolor="g")
plt.hist(n,color="b",edgecolor="g",label="python")
#"auto",(10,200),cumulative=-1,bottom=10,align="mid",histtype="step",orientation="vertical",rwidth=0.8,log=True,

plt.title("histogram plot",fontsize=20)
plt.xlabel("python",fontsize=20)
plt.ylabel("number",fontsize=20)
# plt.axvline(45,color="g",label="line")
# plt.grid()
plt.legend()
plt.show()
