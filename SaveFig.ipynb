# %%
#SAVEFIG
# As the name suggests savefig() method is used to save the figure created after plotting data. 
# The figure created can be saved to our local machines by using this method.

import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,4,3,1,8]
plt.plot(x,y,color="r")
plt.savefig("savefig_pic")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,4,3,1,8]
plt.plot(x,y,color="r")
plt.savefig("savefig_pic1.pdf",dpi=2000,facecolor="g",transparent=True,bbox_inches="tight")
             
plt.show()
